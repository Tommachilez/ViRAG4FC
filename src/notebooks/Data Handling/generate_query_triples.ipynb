# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata

API_KEY = userdata.get('GEMINI_1.5')

# %%
# !git clone https://github.com/Tommachilez/fact-checking-data-framework-vn.git
# %cd /content/fact-checking-data-framework-vn/
# Out:
# Cloning into 'fact-checking-data-framework-vn'...
# remote: Enumerating objects: 555, done.
# remote: Counting objects: 100% (211/211), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 555 (delta 139), reused 113 (delta 62), pack-reused 344 (from 1)
# Receiving objects: 100% (555/555), 5.36 MiB | 16.20 MiB/s, done.
# Resolving deltas: 100% (363/363), done.
# /content/fact-checking-data-framework-vn

# %%
# File paths
INPUT_CSV_PATH = "/content/drive/MyDrive/KLTN_Project/Datasets/vifc.csv"
OUTPUT_JSONL_PATH = "/content/drive/MyDrive/KLTN_Project/Datasets/vifc_queries_triples.jsonl"

# Quota: How many instances to process? (Set to None to process all)
QUOTA = 5000

# %%
# !python -m src.scripts.generation.gemini_generate_query_triples --api_key {API_KEY} \
    --input {INPUT_CSV_PATH} \
    --output {OUTPUT_JSONL_PATH} \
    --quota {QUOTA} \
    --append
# Out:
# Reading from: /content/drive/MyDrive/KLTN_Project/Datasets/vifc.csv
# Writing to: /content/drive/MyDrive/KLTN_Project/Datasets/vifc_queries_triples.jsonl
# Scanning /content/drive/MyDrive/KLTN_Project/Datasets/vifc_queries_triples.jsonl for existing records...
# Found 30938 items already processed.
# Error processing ID 3285: Invalid operation: The `response.parts` quick accessor requires a single candidate, but but `response.candidates` is empty.
# This appears to be caused by a blocked prompt, see `response.prompt_feedback`: block_reason: PROHIBITED_CONTENT
#
# Error processing ID 31084: Expecting property name enclosed in double quotes: line 6 column 3 (char 101)
# Error processing ID 32365: Expecting property name enclosed in double quotes: line 6 column 3 (char 96)
# Error processing ID 33138: Expecting property name enclosed in double quotes: line 6 column 3 (char 85)
# Generating Queries:  77% 3869/5000 [15:55:44<5:15:17, 16.73s/row]
# Run Complete! Processed 3869 new items.
# ...
