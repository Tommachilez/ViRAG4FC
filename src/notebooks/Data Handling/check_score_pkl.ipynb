# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = "/content/drive/MyDrive/KLTN_Project/Datasets"
output_pkl = f"{dataset_path}/viranker_maxp/scores.pkl.gz"

# %%
import gzip
import pickle

# Load the gzipped pickle file defined in the previous cell
with gzip.open(output_pkl, 'rb') as f:
    data = pickle.load(f)

# %%
len(data)
# Out:
# 90182

# %%
count = 0
for item in data.items():
    if count > 5:
        break
    print(item)
    count += 1
# Out:
# ('34703', {'0#1': 9.160768508911133, '870#7': -5.37680721282959, '1006#1': -11.707988739013672, '530#6': -11.813109397888184, '313#4': -11.82744312286377, '679#6': -11.37997055053711, '353#7': -11.812719345092773, '219#1': -11.454612731933594, '242#3': -11.812541007995605, '127#7': -11.804689407348633, '609#3': -11.738794326782227})
# ('34704', {'0#1': 9.61001968383789, '1006#0': -11.623878479003906, '530#0': -11.077919960021973, '313#4': -11.808250427246094, '679#5': -11.58366870880127, '219#1': -11.689910888671875, '242#3': -11.816051483154297, '127#7': -11.790616035461426, '391#6': -11.590001106262207, '61#1': -11.779924392700195, '609#3': -11.66511058807373})
# ...

# %%
firstp_pkl = f"{dataset_path}/viranker_firstp/scores.pkl.gz"

with gzip.open(firstp_pkl, 'rb') as f:
    data = pickle.load(f)

# %%
for item in data.items():
    if count > 5:
        break
    print(item)
    count += 1

# %%
dataset_path = "/content/drive/MyDrive/KLTN_Project/Datasets"
doc_mapping = f"{dataset_path}/viranker_maxp/best_passage.csv"

# %%
import pandas as pd

passage_df = pd.read_csv(doc_mapping)
passage_df.head()
# Out:
#    query_id passage_id      score  \
# 0     34703        0#1   9.160769
# 1     34703      870#7  -5.376807
# 2     34703     1006#1 -11.707989
# 3     34703      530#6 -11.813109
# 4     34703      313#4 -11.827443
#
#                                         passage_text
# 0  bế mạc còn có Bí thư Trung ương Đảng, Trưởng B...
# 1  phát biểu chào mừng Liên hoan, Chủ tịch UBND T...
# 2  Phó Thủ tướng đánh giá cao đóng góp của các tr...
# 3  đẩy hợp tác để tìm ra cách thức phát triển kin...
# 4  chấm dứt hợp đồng, khiếu kiện chủ đầu tư về cá...

# %%
passage_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992229 entries, 0 to 992228
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   query_id      992229 non-null  int64
#  1   passage_id    992229 non-null  object
#  2   score         992229 non-null  float64
#  3   passage_text  992229 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 30.3+ MB
