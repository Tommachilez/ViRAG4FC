# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Tommachilez/fact-checking-data-framework-vn.git
# %cd /content/fact-checking-data-framework-vn/
# Out:
# Cloning into 'fact-checking-data-framework-vn'...
# remote: Enumerating objects: 606, done.
# remote: Counting objects: 100% (262/262), done.
# remote: Compressing objects: 100% (187/187), done.
# remote: Total 606 (delta 179), reused 137 (delta 75), pack-reused 344 (from 1)
# Receiving objects: 100% (606/606), 5.37 MiB | 11.78 MiB/s, done.
# Resolving deltas: 100% (403/403), done.
# /content/fact-checking-data-framework-vn

# %%
dataset_path = "/content/drive/MyDrive/KLTN_Project/Datasets"
test_triples = f"{dataset_path}/test_triples.jsonl"

# %%
mp_checkpoint_dir = "/content/drive/MyDrive/KLTN_Project/Models/viranker_maxp_checkpoints"

# %% [markdown]
# # Visualize

# %%
mp_output_dir = f"{dataset_path}/viranker_maxp"
firstp_image = f"{mp_output_dir}/firstp.png"
maxp_image = f"{mp_output_dir}/maxp.png"

# %%
# !python -m src.scripts.viranker.visualize \
    --trained_model {mp_checkpoint_dir} \
    --jsonl {test_triples} \
    --output_image {firstp_image}
# Out:
# 2025-12-27 03:26:14.691487: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-27 03:26:14.710048: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766805974.731762    5525 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766805974.738484    5525 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python -m src.scripts.viranker.visualize \
    --trained_model {mp_checkpoint_dir} \
    --jsonl {test_triples} \
    --output_image {maxp_image} \
    --max_length 512 \
    --maxp
# Out:
# 2025-12-27 07:22:20.608575: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-27 07:22:20.626702: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766820140.648437   63492 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766820140.654983   63492 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # Scoring

# %%
doc_mapping = f"{dataset_path}/unique_doc_mapping.csv"
query_mapping = f"{dataset_path}/train_query_mapping.csv"
train_triples = f"{dataset_path}/training_triples.jsonl"

# %%
# !python -m src.scripts.filtering.score_viranker \
    --csv {csv_path} \
    --mining_jsonl {test_triples} \
    --model_path {mp_checkpoint_dir} \
    --output_dir {mp_output_dir} \
    --batch_size 32 \
    --maxp \
    # --append
