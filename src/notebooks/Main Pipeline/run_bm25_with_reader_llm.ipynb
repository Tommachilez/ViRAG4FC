# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyserini faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.7/159.7 MB 6.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 92.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.2/412.2 kB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 96.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 76.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.8/196.8 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.3/96.3 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 6.2 MB/s eta 0:00:00
# ...

# %%
import os

def install_java():
  # !apt update -qq
  # !apt-get install -y openjdk-21-jdk-headless -qq > /dev/null
  os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-21-openjdk-amd64"
  # !java -version

install_java()
# Out:
# 6 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# openjdk version "21.0.9" 2025-10-21
# OpenJDK Runtime Environment (build 21.0.9+10-Ubuntu-122.04)
# OpenJDK 64-Bit Server VM (build 21.0.9+10-Ubuntu-122.04, mixed mode, sharing)

# %%
# !git clone https://github.com/Tommachilez/fact-checking-data-framework-vn.git
# %cd /content/fact-checking-data-framework-vn/
# Out:
# Cloning into 'fact-checking-data-framework-vn'...
# remote: Enumerating objects: 630, done.
# remote: Counting objects: 100% (286/286), done.
# remote: Compressing objects: 100% (203/203), done.
# remote: Total 630 (delta 197), reused 151 (delta 83), pack-reused 344 (from 1)
# Receiving objects: 100% (630/630), 5.38 MiB | 14.06 MiB/s, done.
# Resolving deltas: 100% (421/421), done.
# /content/fact-checking-data-framework-vn

# %%
from google.colab import userdata

GEMINI_KEY = userdata.get('GEMINI_1.5')

dataset_path = "/content/drive/MyDrive/KLTN_Project/Datasets"
VNCORE_MODEL_PATH = "/content/drive/MyDrive/KLTN_Project/Models/vncorenlp_models"
stopwords_path = f"{dataset_path}/stopwords-vi.txt"
doc_mapping = f"{dataset_path}/unique_doc_mapping.csv"
query_mapping = f"{dataset_path}/test_query_mapping.csv"
output_dir = f"{dataset_path}/gemini_labeling_output_bm25"
vifc_test = f"{dataset_path}/vifc_test_set_with_labels.csv"
index_dir = f"{dataset_path}/vn_mining_test/pyserini_index"
segmented_queries = f"{dataset_path}/vn_mining_test/segmented_test_queries.tsv"

# %%
# !python -m src.scripts.bm25_rag_inference \
    --index_dir {index_dir} \
    --segmented_queries {segmented_queries} \
    --raw_queries {query_mapping} \
    --doc_mapping {doc_mapping} \
    --labels {vifc_test} \
    --output_dir {output_dir} \
    --api_key {GEMINI_KEY}
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# 2025-12-28 09:32:28.709056: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-28 09:32:28.714074: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-28 09:32:28.727626: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766914348.750027    2350 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
