# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datasets import load_dataset

vifactcheck = load_dataset("tranthaihoa/vifactcheck")
# Out:
# README.md:   0%|          | 0.00/853 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/8.07M [00:00<?, ?B/s]
# data/dev-00000-of-00001.parquet:   0%|          | 0.00/1.23M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/1447 [00:00<?, ? examples/s]

# %%
viwikifc = "/content/drive/MyDrive/KLTN_Project/Datasets/ViWikiFC/train_final_pro.csv"
vinumfcr = "/content/drive/MyDrive/KLTN_Project/Datasets/ViNumFCR/Data_10008_gốc/train_evidence.jsonl"

# %%
import pandas as pd

viwikifc_df = pd.read_csv(viwikifc)
viwikifc_df.head()
# Out:
#                 pairID                                           evidence  \
# 0   uit_424_27_39_3_11  Chế độ quân chủ chuyên chế đã tỏ ra quá già cỗ...
# 1   uit_817_41_89_5_11  Một cuộc đảo chính lật đổ nền quân chủ và thàn...
# 2   uit_854_44_98_3_12  Năm 1956, sau khi Pháp hoàn tất rút quân khỏi ...
# 3  uit_948_53_29_11_12  Các hải tặc người Mã Lai và Dayak Biển từ hang...
# 4      uit_65_5_1_4_11  Singapore là quốc gia có mức độ đô thị hóa rất...
#
#   gold_label                                        link  \
# 0   Supports         https://vi.wikipedia.org/Trung Quốc
# 1   Supports          https://vi.wikipedia.org/thế kỷ XX
# 2   Supports  https://vi.wikipedia.org/quần đảo Hoàng Sa
# 3   Supports             https://vi.wikipedia.org/Borneo
# 4   Supports          https://vi.wikipedia.org/Singapore
#
#                                              context        sentenceID  \
# 0  Cuối thời nhà Thanh, do sự lạc hậu về khoa học...   uit_424_27_39_3
# ...

# %%
vinumfcr_df = pd.read_json(vinumfcr, lines=True)
vinumfcr_df.head()
# Out:
#                                            paragraph envidence start 4  \
# 0  Lần đầu tiên kể từ năm 2017 và là lần thứ hai ...
# 1  Lần đầu tiên kể từ năm 2017 và là lần thứ hai ...               NaN
# 2  Kịch bản tương tự tái hiện ở giải thế giới ở A...
# 3  Kịch bản tương tự tái hiện ở giải thế giới ở A...               NaN
# 4  Gia Thành 25 tuổi, người Bắc Ninh, đã đoạt HC ...
#
#   envidence start 3                                               link  \
# 0                    https://vnexpress.net/luc-si-viet-nam-vo-dich-...
# 1               NaN  https://vnexpress.net/luc-si-viet-nam-vo-dich-...
# 2                    https://vnexpress.net/luc-si-viet-nam-vo-dich-...
# 3               NaN  https://vnexpress.net/luc-si-viet-nam-vo-dich-...
# 4                    https://vnexpress.net/luc-si-viet-nam-vo-dich-...
#
#   envidence start 2 annotator_labels          label envidence start 1  \
# 0               101      [Supported]      Supported                 0
# ...
