# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Tommachilez/fact-checking-data-framework-vn.git
# %cd /content/fact-checking-data-framework-vn/
# Out:
# Cloning into 'fact-checking-data-framework-vn'...
# remote: Enumerating objects: 635, done.
# remote: Counting objects: 100% (291/291), done.
# remote: Compressing objects: 100% (208/208), done.
# remote: Total 635 (delta 200), reused 153 (delta 83), pack-reused 344 (from 1)
# Receiving objects: 100% (635/635), 5.39 MiB | 12.02 MiB/s, done.
# Resolving deltas: 100% (424/424), done.
# /content/fact-checking-data-framework-vn

# %%
dataset_path = "/content/drive/MyDrive/KLTN_Project/Datasets"
test_triples = f"{dataset_path}/test_triples.jsonl"

# %%
fp_checkpoint_dir = "/content/drive/MyDrive/KLTN_Project/Models/viranker_firstp_checkpoints/checkpoint-17000"
mp_checkpoint_dir = "/content/drive/MyDrive/KLTN_Project/Models/viranker_maxp_checkpoints"

# %% [markdown]
# # Visualize

# %%
# !python -m src.scripts.viranker.visualize \
    --trained_model {fp_checkpoint_dir} \
    --jsonl {test_triples}
# Out:
# 2025-12-26 13:28:14.143101: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-26 13:28:14.161967: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766755694.183504    1999 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766755694.190000    1999 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766755694.206722    1999 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766755694.206762    1999 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766755694.206765    1999 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766755694.206768    1999 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-26 13:28:14.211663: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading data from /content/drive/MyDrive/KLTN_Project/Datasets/test_triples.jsonl...
# Total queries for evaluation: 7687
# --- Evaluating Trained Model: /content/drive/MyDrive/KLTN_Project/Models/viranker_firstp_checkpoints/checkpoint-17000 ---
# The tokenizer you are loading from '/content/drive/MyDrive/KLTN_Project/Models/viranker_firstp_checkpoints/checkpoint-17000' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Evaluating: 100% 7687/7687 [2:01:40<00:00,  1.05it/s]
# --- Evaluating Base Model: namdp-ptit/ViRanker ---
# config.json: 100% 796/796 [00:00<00:00, 4.42MB/s]
# model.safetensors: 100% 2.27G/2.27G [00:06<00:00, 331MB/s]
# tokenizer_config.json: 1.17kB [00:00, 6.48MB/s]
# sentencepiece.bpe.model: 100% 5.07M/5.07M [00:00<00:00, 7.84MB/s]
# tokenizer.json: 100% 17.1M/17.1M [00:00<00:00, 33.8MB/s]
# special_tokens_map.json: 100% 964/964 [00:00<00:00, 10.8MB/s]
# README.md: 6.91kB [00:00, 11.3MB/s]
# Evaluating: 100% 7687/7687 [2:01:44<00:00,  1.05it/s]
#
# ==================================================
# RESULTS SUMMARY
# ==================================================
# Metric     | Base       | Trained    | Gain
# --------------------------------------------------
# MRR@3      | 0.8771     | 0.9608     | +9.5%
# NDCG@3     | 0.8937     | 0.9668     | +8.2%
# MRR@5      | 0.8832     | 0.9626     | +9.0%
# NDCG@5     | 0.9046     | 0.9701     | +7.2%
# MRR@10     | 0.8870     | 0.9636     | +8.6%
# NDCG@10    | 0.9137     | 0.9725     | +6.4%
# ==================================================
#
# Figure(1200x600)

# %%
# !python -m src.scripts.viranker.visualize \
    --trained_model {fp_checkpoint_dir} \
    --jsonl {test_triples} \
    --max_length 512 \
    --maxp
# Out:
# 2025-12-26 17:33:18.890052: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-26 17:33:18.908835: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766770398.930661   62383 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766770398.937277   62383 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766770398.954187   62383 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766770398.954217   62383 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766770398.954220   62383 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766770398.954223   62383 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-26 17:33:18.959243: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading data from /content/drive/MyDrive/KLTN_Project/Datasets/test_triples.jsonl...
# Total queries for evaluation: 7687
# --- Evaluating Trained Model: /content/drive/MyDrive/KLTN_Project/Models/viranker_firstp_checkpoints/checkpoint-17000 ---
# The tokenizer you are loading from '/content/drive/MyDrive/KLTN_Project/Models/viranker_firstp_checkpoints/checkpoint-17000' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Evaluating: 100% 7687/7687 [3:10:49<00:00,  1.49s/it]
# --- Evaluating Base Model: namdp-ptit/ViRanker ---
# Evaluating: 100% 7687/7687 [3:10:42<00:00,  1.49s/it]
#
# ==================================================
# RESULTS SUMMARY
# ==================================================
# Metric     | Base       | Trained    | Gain
# --------------------------------------------------
# MRR@3      | 0.8918     | 0.9626     | +7.9%
# NDCG@3     | 0.9063     | 0.9678     | +6.8%
# MRR@5      | 0.8975     | 0.9644     | +7.5%
# NDCG@5     | 0.9165     | 0.9711     | +6.0%
# MRR@10     | 0.9007     | 0.9655     | +7.2%
# NDCG@10    | 0.9243     | 0.9737     | +5.3%
# ==================================================
#
# Figure(1200x600)

# %% [markdown]
# # Scoring

# %%
train_triples = f"{dataset_path}/training_triples.jsonl"
fp_output_dir = f"{dataset_path}/viranker_firstp"
mp_output_dir = f"{dataset_path}/viranker_maxp"

# %%
doc_mapping = f"{dataset_path}/unique_doc_mapping.csv"
query_mapping = f"{dataset_path}/train_query_mapping.csv"

# %%
# !python -m src.scripts.filtering.score_viranker \
    --doc_mapping {doc_mapping} \
    --query_mapping {query_mapping} \
    --mining_jsonl {train_triples} \
    --model_path {fp_checkpoint_dir} \
    --output_dir {fp_output_dir} \
    --batch_size 32 \
    # --append
# Out:
# Loading ViRanker from checkpoint: /content/drive/MyDrive/KLTN_Project/Models/viranker_firstp_checkpoints/checkpoint-17000 on cuda...
# Output Mode: Raw Logits
# The tokenizer you are loading from '/content/drive/MyDrive/KLTN_Project/Models/viranker_firstp_checkpoints/checkpoint-17000' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# 2025-12-27 01:31:14.978066: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-27 01:31:14.995716: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766799075.016780    4017 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766799075.023066    4017 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766799075.039333    4017 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766799075.039370    4017 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766799075.039375    4017 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766799075.039379    4017 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-27 01:31:15.044428: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading document mapping from /content/drive/MyDrive/KLTN_Project/Datasets/unique_doc_mapping.csv...
# Loading query mapping from /content/drive/MyDrive/KLTN_Project/Datasets/train_query_mapping.csv...
# Loaded 129021 queries into mapping.
# Counting lines in /content/drive/MyDrive/KLTN_Project/Datasets/training_triples.jsonl...
# Starting scoring loop. Output: /content/drive/MyDrive/KLTN_Project/Datasets/viranker_firstp/scores.pkl.gz
# Scoring: 100% 92261/92261 [12:33:44<00:00,  2.04queries/s]
# Saving final scores for 90182 queries...
# Total Queries Scored: 90182
# Skipped (Query not in mapping): 0

# %%
# !python -m src.scripts.filtering.score_viranker \
    --doc_mapping {doc_mapping} \
    --query_mapping {query_mapping} \
    --mining_jsonl {train_triples} \
    --model_path {fp_checkpoint_dir} \
    --output_dir {mp_output_dir} \
    --batch_size 32 \
    --maxp \
    --append
# Out:
# Loading ViRanker from checkpoint: /content/drive/MyDrive/KLTN_Project/Models/viranker_firstp_checkpoints/checkpoint-17000 on cuda...
# Output Mode: Raw Logits
# The tokenizer you are loading from '/content/drive/MyDrive/KLTN_Project/Models/viranker_firstp_checkpoints/checkpoint-17000' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# 2025-12-31 12:49:28.685683: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-31 12:49:28.703243: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767185368.724414    1336 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767185368.730697    1336 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767185368.746764    1336 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767185368.746796    1336 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767185368.746800    1336 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767185368.746804    1336 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-31 12:49:28.751789: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading document mapping from /content/drive/MyDrive/KLTN_Project/Datasets/unique_doc_mapping.csv...
# Loading query mapping from /content/drive/MyDrive/KLTN_Project/Datasets/train_query_mapping.csv...
# Loaded 129021 queries into mapping.
# Append mode: Loading scores from /content/drive/MyDrive/KLTN_Project/Datasets/viranker_maxp/scores.pkl.gz...
# Found 90182 existing queries in history.
# MaxP Enabled: Best passages will be saved to /content/drive/MyDrive/KLTN_Project/Datasets/viranker_maxp/best_passage.csv
# Counting lines in /content/drive/MyDrive/KLTN_Project/Datasets/training_triples.jsonl...
# Starting scoring loop. Output: /content/drive/MyDrive/KLTN_Project/Datasets/viranker_maxp/scores.pkl.gz
# Scoring: 100% 92261/92261 [00:19<00:00, 4656.34queries/s]
# Saving final scores for 90182 queries...
# Total Queries Scored: 0
# Skipped (Query not in mapping): 0
